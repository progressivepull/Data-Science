# %% [markdown]
# # Ch02/02_04 Learn Boolean Indexing

# %%
import numpy as np

# %% [markdown]
# Sometimes you'd like to select parts of an array not by indices, but by some logic, say all the values that are bigger than some threshold.

# %% [markdown]
# For this, we're going to use Boolean indexing. Let's see how it works. So we **import Numpy and create an array with three elements**. Let's run it.

# %%
arr = np.arange(3)
arr
# Out:
# array([0, 1, 2])

# %% [markdown]
# You can index an array with another array in the same shape **containing Boolean values true or false**. So here's the array and I'm adding it in index with true, false, true and I'm going to run it. I'm going to get only the elements where the index was true. For now this does not seem that helpful, but let's see one more thing.

# %%
import numpy as np

arr = np.arange(3)
arr
# Out:
# array([0, 1, 2])

# %%
arr[[True, False, True]]
# Out:
# array([0, 2])

# %% [markdown]
# And this will make it super useful if I'm doing array bigger or equal to one. I'm going to get a Boolean array with false through and through and now I can combine these two and say array at the location where the array is bigger or equal to.

# %%
arr >= 1
# Out:
# array([False,  True,  True])

# %% [markdown]
# And I'm getting one and two, but not the zero.

# %%
arr[arr >= 1]
# Out:
# array([1, 2])

# %% [markdown]
# You can combine these conditions or masks using Boolean operators. However these are not the normal Boolean operators that we have in Python. You're going to use **ampersand (&)** for **AND** the **vertical bar (|)** for **OR** and the **tilde(~)** for NOT.

# %% [markdown]
# So I have a bigger array now with 10 and I'm saying all the elements that are bigger than two and smaller than seven. Note that the parenthesis here is mandatory.

# %%
arr = np.arange(10)

arr[(arr>2) & (arr<7)]
# Out:
# array([3, 4, 5, 6])

# %%
arr[(arr>7) | (arr<2)]
# Out:
# array([0, 1, 8, 9])

# %% [markdown]
# So everything that is not bigger than 7 usually going to write it as everything that is smaller or equal to 8. And here is an example of negation.

# %%
arr[~(arr>7)]
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# # Standard score
# https://en.wikipedia.org/wiki/Standard_score
#   Let's do a more realistic example. We're going to find outliers using the standard score.

# %% [markdown]
#  First, we're going to create our data. So I'm going to create. And array of 1000 elements with values between 0 and 10 with the normal distribution and then I'm going to add 2 outliers at location 33 and location 832.

# %%
values = np.random.normal(0, 10, 1_000)
values[33] = 1038
values[832] = -3423

# %% [markdown]
# Now I'm going to calculate my mask so the mask is where the absolute value of the value itself minus the mean, meaning the distance from the mean is bigger than two times the standard deviation inside the array, and then I'm going to calculate the values in the mask. I'm going to see exactly my outliers.

# %%
mask = np.abs(values - values.mean()) > (2 * values.std())
values[mask]
# Out:
# array([ 1038., -3423.])

# %% [markdown]
# Over there I can even use this mask to change the values, let's say to the mean of the current array. This is an example for the power of Boolean indexing. You can do a lot of things in a very few line apart from the cool effect. This is also very fast. In numerical Python you try hard not to do any follow-ups. This method of computation is called vectorization and once you use it, everything runs at the C. For photon level of Numpy.

# %%
values[mask] = values.mean()

# %%
values
# Out:
# array([-1.24151744e+01, -5.42715440e+00, -2.10605999e+00,  9.30479524e-01,
#        -9.31545035e+00, -1.16376728e+01,  6.34152402e+00,  4.79516972e+00,
#         1.52506419e+01, -2.20290294e+00,  1.52115650e+00,  1.41811488e+01,
#        -4.53863647e+00,  1.10360531e+01,  3.19759658e+00,  1.64336588e+01,
#        -1.20022750e+00, -9.31617544e-01,  6.49295023e+00,  2.50491436e+00,
#        -1.33440302e+01, -5.04832123e+00,  5.37535185e+00, -2.90431152e+00,
#        -1.42853300e+01, -7.95079632e+00, -1.06373360e+01,  2.20321926e+00,
#         2.05997711e+01,  1.01998094e+01,  1.06987001e+01,  1.25616240e+01,
#         1.06430223e+00, -2.37295772e+00,  1.22791791e+00, -8.08582967e+00,
#        -1.59959886e+01, -1.35194268e+01,  1.49027277e+01,  3.65121249e+00,
#        -1.03972089e+01, -3.97403849e+00, -5.28042897e+00,  8.10545529e+00,
#         2.13794271e+00,  2.68200285e+00,  6.29726393e+00, -1.27596273e+01,
#        -4.94719453e+00, -3.81283790e+00,  9.00123118e-01,  5.06563625e-01,
#         7.07070854e+00,  5.18755671e-01, -3.12572594e+01,  1.65524941e+01,
#         1.53578513e+01, -1.54998965e+01, -1.65658580e+01, -2.05140360e+00,
#         1.32320934e+01, -7.24967001e-01,  1.16887749e+01, -1.15361297e+01,
#         8.34480302e+00, -2.36927899e+00, -6.49017817e+00, -1.01457319e+01,
#        -8.30677605e+00, -1.20467615e+01, -5.68081941e+00,  2.22477240e+00,
#         6.74156283e-01, -9.17538707e+00, -7.75730192e+00,  6.15464347e+00,
#        -1.01606737e+01, -2.77043031e+00, -6.50206551e+00,  3.82070264e+00,
#        -2.92863813e-01, -6.72603867e+00, -6.07129157e+00, -7.94511400e+00,
#         2.32917530e+00,  8.08526339e+00,  9.20854808e+00,  8.38300571e+00,
#        -1.50075421e+01, -6.12232831e-01,  6.13087847e+00, -5.11722527e+00,
#         8.42544020e+00, -1.01601577e+01, -5.27973452e+00,  2.10872571e+00,
#        -2.75769590e+00,  5.03164915e+00,  1.12594279e+01,  3.71789936e+00,
#         7.39407121e+00, -3.50865487e+00,  7.61931315e+00,  3.76172388e+00,
#        -9.06930068e+00,  8.43368277e+00, -3.78259797e+00,  3.26660989e+00,
#         4.41699611e+00,  1.04785111e+01,  9.99817723e+00,  1.22498465e+01,
#        -8.31389877e+00,  3.04656569e+00,  4.68772996e+00, -2.08798705e+00,
#         5.61734008e+00, -1.85317685e+00,  6.30622671e+00, -4.90144783e-01,
#         4.57186812e+00,  5.93156038e+00, -5.63467818e+00,  1.48086202e+01,
#        -8.66519220e+00,  1.06891145e+01, -4.66353873e+00,  9.60940672e+00,
#        -6.94193633e+00, -9.11569040e+00,  3.28802660e+00,  9.37391392e+00,
#        -2.09196038e+00, -1.35207580e-01,  1.20329533e+00,  3.48293142e+00,
#        -3.09228442e+00, -2.21923464e+00,  1.47260030e+00, -8.48183492e+00,
#         9.77615186e+00,  5.69550907e+00,  5.98743860e+00, -1.09972162e+01,
#        -3.25245140e+00, -2.15487805e+00, -3.69235092e-01,  1.61526018e+00,
#        -6.60443090e-01,  1.10875698e+01, -1.05553658e+01, -2.76380831e+00,
#         5.79936977e+00, -4.53016707e+00, -7.44419416e-01,  2.21427111e-01,
#         1.09456846e+01, -1.32744980e+00, -8.21422757e+00,  7.44384833e+00,
#         1.22938484e+01,  4.75339221e+00, -1.03356380e+01,  1.56516570e+00,
#        -2.12656382e+01,  6.44485266e+00, -5.58868569e+00,  1.49870111e+01,
#         1.30270944e+00, -4.69830906e+00, -1.64911179e+01,  3.29142498e+00,
#        -8.71585489e+00, -5.68468130e-01, -6.03158168e+00, -1.43433655e-01,
#         4.47005833e+00, -1.15357250e+01, -1.17298172e+00, -1.72382460e+00,
#        -5.91898937e+00,  1.21132734e+01,  9.67534132e-01,  2.04462297e+00,
#         4.70839725e+00, -6.24646945e-01,  6.33123931e+00,  5.12671454e-01,
#         2.16089869e+01,  7.52111352e+00,  7.68371763e+00,  3.37276031e+00,
#         8.90425621e+00,  4.22261067e+00, -8.07108608e+00,  7.92469119e+00,
#         7.66290666e+00,  7.02592071e+00,  2.65180135e+00,  5.06254430e+00,
#         7.80223491e+00, -4.63470634e+00,  8.85861975e-01,  1.36128719e+01,
#         9.06807257e+00, -1.15508342e+01, -4.46883325e-01, -3.73435380e+00,
#        -1.23107550e+01, -8.92497376e+00, -1.25935122e+01,  3.90696713e+00,
#         1.21514002e+01, -8.95875148e+00,  9.48779232e+00,  1.53172343e+01,
#        -1.69567777e+01, -8.71327743e+00,  9.38645763e+00,  3.17594918e+00,
#         1.93148885e+00,  6.54057910e+00, -3.36713585e-01, -2.03386446e+01,
#         1.08097308e+01, -1.34623833e+01,  1.28437054e+01,  2.97739061e+00,
#        -6.35729269e+00,  5.21361411e+00, -8.69925768e+00, -1.59910213e+01,
#         3.34592686e+00, -8.22428805e-01,  7.41483163e+00, -1.00063596e+01,
#        -1.50984714e+00,  7.77541819e-02,  1.39180277e+00, -3.03969609e+00,
#         3.47153727e+00, -8.38386967e+00,  1.21050141e+01,  5.72651869e+00,
#         2.06015894e+00,  1.75760604e+01, -9.45977148e+00, -1.08974040e+00,
#        -9.20665945e+00, -9.40915346e+00, -1.47517640e+00, -1.72608246e+01,
#        -4.75999991e+00, -7.23736810e+00,  4.16177490e-01,  5.05396051e+00,
#        -5.62219508e+00,  6.96093918e+00,  9.83630522e+00,  8.18765536e+00,
#         2.51679241e+00,  9.05995252e+00,  2.68097166e+00, -5.18444654e+00,
#         2.12654887e+00, -2.68829313e+00,  2.65700141e+00,  8.33863216e-01,
#         1.41396566e+01, -1.90639121e+01,  1.02731895e+01, -6.26591868e-01,
#        -1.51618412e+01,  5.39603936e+00, -4.21486997e+00, -6.84206045e+00,
#         6.21632225e+00,  7.11744186e+00, -1.46202839e+00,  2.40578737e+00,
#         2.63430666e+00,  1.11615883e+01,  1.32381259e+00, -1.11993159e+01,
#        -2.63621141e+00,  6.34880852e+00, -1.29809169e+00, -5.91914663e-01,
#         8.04484134e+00, -2.83581686e+00, -1.02995649e+01, -1.88651728e+01,
#         4.93534235e+00,  8.08711770e+00,  9.19769361e+00,  1.71074596e+01,
#         5.08138933e+00,  4.79659273e+00,  8.17957968e+00,  1.76164143e+01,
#         1.11030798e+01, -2.24517901e+01,  5.89441101e+00,  2.86113365e+01,
#         8.72384164e+00, -2.00585594e+01,  3.40880141e+00,  6.88356967e+00,
#        -6.20312632e+00,  8.55229242e+00, -2.30534945e+01, -6.37122123e+00,
#         6.37395476e+00, -3.88402963e+00, -3.60960293e+00, -6.39451227e+00,
#         1.20229285e+01,  4.36608671e+00,  1.05224573e+00,  7.72998557e+00,
#         1.06183418e+00,  1.18836725e+01,  4.42936702e+00,  2.01156855e+01,
#         8.36703159e+00,  1.47494067e+01, -2.19957337e+01, -4.23376131e+00,
#         1.41795503e+01, -3.49334240e-01, -7.92953309e+00, -6.50548053e+00,
#        -4.97344279e+00, -5.95839354e+00, -5.62848660e+00,  2.39069515e+00,
#         2.02605688e+01, -1.05571922e+01,  1.92591170e+01,  9.13773710e+00,
#        -1.68458515e+01,  4.32350247e+00,  1.02642984e+01, -9.16510208e+00,
#        -1.54754443e+00, -9.37453779e+00,  7.98312310e+00,  6.38117757e+00,
#         6.91906677e-01,  2.27129322e+00,  8.91365347e+00,  6.93089995e+00,
#         1.19602746e+01, -8.52303455e+00,  1.19697869e+01,  6.62952562e-01,
#        -2.49738708e+00, -8.35878392e+00,  6.58037791e+00, -3.06006394e-01,
#         1.57930102e+01,  9.39794283e-01, -2.69212368e+00,  7.38799338e+00,
#        -9.32821491e+00,  1.75693489e+01, -6.62897005e+00, -1.22103734e+01,
#        -2.99784791e-01, -2.07651134e+01, -3.91683020e-01, -5.62066270e+00,
#         1.76282635e-01,  1.02307496e+01,  1.09548556e+01,  2.06627759e+01,
#         2.47922325e+00, -1.11979224e+01,  3.29262306e-02, -5.62477512e+00,
#        -6.26600637e-01, -1.62663674e+01, -8.43448853e-01,  1.31359243e+00,
#        -1.34417743e+00,  6.45460385e+00,  9.42241386e+00,  1.67325513e-01,
#         4.13554787e+00,  6.53110856e+00, -1.41092811e+01,  5.78992609e+00,
#        -2.80673753e+00,  6.09809341e+00,  3.39840052e+01, -2.37732801e+01,
#         1.23213062e+00, -1.71699412e+00, -1.56566881e+00,  1.57934204e+01,
#        -2.01868194e+00,  5.58430876e+00, -1.73095391e+01, -1.40909389e+01,
#         4.16331177e-01,  1.57369829e+01, -1.81218365e+00, -2.55941509e+00,
#        -2.27404928e+00, -3.58594060e+00, -1.96956397e-01, -1.23522887e+01,
#        -1.20158723e+00, -1.62887303e+01, -3.22578962e+00,  2.77938456e+00,
#         8.41345610e-01, -1.09835295e+00,  3.05629613e+00,  5.42040487e+00,
#         1.50033361e+01, -4.45963468e+00, -1.25048300e+01,  1.22492728e+01,
#        -5.87823905e+00, -1.52076525e+01,  1.01198122e+01, -2.01077603e+00,
#         4.58447629e+00,  5.80928772e+00, -6.15092031e+00,  8.70494563e+00,
#        -1.67707568e+01,  8.55986460e+00,  6.95103912e+00,  5.56268213e-01,
#        -2.09633993e+00, -1.17886359e+01, -8.64108546e+00, -1.13527109e+00,
#         1.90966393e+01,  1.98565345e+01, -1.29794875e+00,  3.45418972e+00,
#         5.11726227e+00,  3.04694543e+00,  2.49925573e+00,  9.63772905e-02,
#        -1.28966076e+01, -5.00165688e+00,  7.17522344e+00,  1.37284679e+01,
#         1.09077399e+01, -1.93498681e+01, -1.16419863e+01,  2.78336420e+00,
#         7.58095454e+00, -4.26256938e+00, -4.14440258e+00,  4.43110837e-01,
#         4.16408277e+00, -2.17571134e+01,  7.03870630e+00,  4.51074851e+00,
#        -1.13378494e+01,  3.86943251e+00,  7.51733036e+00,  7.14471819e+00,
#         8.54236090e-01, -7.96340030e+00,  3.60518906e+00, -4.18991285e+00,
#        -6.00819309e+00, -9.90278817e+00,  1.39751244e+01,  3.52268521e+00,
#        -2.91232276e+01,  1.27866278e+00,  2.15642173e+01,  1.38204495e+00,
#        -8.08343956e+00, -3.46914821e+00, -1.34102689e+00, -1.22503815e+01,
#        -4.99474105e+00, -1.48828374e+01, -4.82117194e+00,  1.27878704e+01,
#        -3.26621252e+00, -3.14962404e+00, -1.41467719e+01, -1.47937902e+01,
#         2.87122228e+00,  1.03622778e+01, -2.61397851e+00,  5.58145219e+00,
#        -5.30236719e+00,  6.77888950e+00,  5.88635274e-02, -1.99090376e-01,
#         6.69345986e+00,  6.30085329e+00,  1.22174057e+01,  1.30655262e+01,
#         3.26782409e+00,  9.49698252e+00,  7.24094543e+00,  5.54591523e+00,
#         8.22755222e+00, -6.33057660e+00,  1.29655311e+01,  1.03310614e+01,
#        -8.65014472e+00,  1.78064713e+01,  3.49563808e+00, -9.39464699e+00,
#        -4.24285651e+00, -4.21227223e+00, -3.50097982e-01, -7.16557154e-01,
#         7.05005115e+00,  2.34797500e+00,  1.38126312e+01,  1.12105895e+01,
#        -9.17094444e+00,  9.96811170e+00,  4.81082240e+00,  1.51440832e+01,
#         4.80092097e+00,  9.91324336e+00, -1.20894045e+01, -1.51535387e+01,
#        -1.61273443e-02,  6.54020898e+00, -6.40908062e+00, -1.57516386e+01,
#        -7.16530519e+00,  1.87397016e+01, -4.85067766e-02,  1.05738535e+01,
#         5.70432835e+00, -9.96129013e+00,  7.66910570e+00,  4.55192021e+00,
#         8.34639784e-01,  1.03590595e+01, -4.87142199e+00,  1.41027976e+00,
#        -2.99628716e+00, -8.60320960e+00,  9.92249812e+00, -4.04056078e+00,
#        -6.16775510e+00,  5.14378171e+00, -7.65517822e+00, -6.76456073e+00,
#         1.74905002e+01,  1.46973932e+00, -4.29875987e+00,  2.14015149e+01,
#         1.47299484e+01, -1.44322730e+01,  4.99027653e+00,  2.09393244e+01,
#         1.94195420e+01,  1.35363578e+01,  1.09891161e+00,  2.90081764e+01,
#         4.21765396e+00, -2.07356719e+01, -4.47334452e+00, -1.30529221e+01,
#         9.42359765e-01,  1.43967765e+01, -7.16505259e+00, -6.60144618e+00,
#        -3.84645111e-01,  4.89224924e+00, -1.14212161e+01,  2.94628275e+00,
#         1.60605626e+01,  8.21489351e+00,  9.11063416e+00,  3.59488016e+00,
#        -1.04719845e+01, -8.92280742e+00, -6.93175907e+00,  9.30945479e+00,
#         1.98985077e+01,  5.89836191e+00,  2.27880401e+00,  1.04821203e+01,
#        -4.50045797e+00,  4.64204480e+00,  5.39019292e+00, -1.74062491e+00,
#        -1.06302726e+01, -3.95775266e+00,  9.19876789e+00,  3.27844329e+00,
#        -3.46936572e+00, -1.02352299e+01, -9.24192719e-01,  1.56650922e+01,
#         1.05740196e+01,  1.89429164e+00, -8.63474885e+00,  7.18360859e+00,
#         8.01899196e+00, -1.36319850e+00,  6.80481250e+00,  4.84376143e+00,
#         9.15318540e+00, -3.23606821e+00, -1.41849703e+01,  1.10941510e+01,
#         4.03131081e-01, -6.27875192e+00, -1.36083098e+00,  5.60880777e+00,
#         8.15477872e+00, -6.36884624e+00, -1.22033865e+01,  1.07180105e+01,
#        -3.04773357e+01, -4.34547626e+00,  3.00665604e+00,  8.64042208e+00,
#         4.90970397e+00,  1.29693955e+00,  1.42279606e+00, -2.11014577e+01,
#         1.45570948e+01, -3.19305785e+00, -2.56222663e+00,  1.04721455e+01,
#        -1.19499163e+01, -3.44985750e+00, -5.12612429e+00, -6.07205213e+00,
#         4.56915128e+00, -5.71288325e+00, -1.38105859e+01,  5.56291724e+00,
#         3.73548683e+00,  3.26804509e+00, -1.37260941e+01, -1.56196585e+01,
#        -7.63184513e+00, -2.01739459e+01,  8.88887964e+00,  1.73332142e-01,
#        -3.26811215e+00,  1.06748335e+01, -1.77558467e+00,  1.33549236e+01,
#         4.05013742e+00, -1.77604146e+01,  1.28512026e+00, -7.82564921e+00,
#        -9.30782927e+00, -1.19855324e+01,  7.09289879e-02,  6.32424188e+00,
#         2.54867410e+00,  4.00750963e+00,  5.37883742e+00,  2.27287043e+00,
#        -2.61577365e+01, -4.25918370e+00,  1.04444654e+01,  8.52636474e-01,
#         3.02637288e+00,  8.69760345e+00, -1.98267695e+00,  3.69800321e+00,
#        -1.62525147e+01,  1.08504877e+00,  8.86990484e-01, -4.62174495e+00,
#        -1.62146459e+01, -2.35361210e+00,  2.08105888e+00, -1.86522558e+01,
#        -8.64635738e+00, -3.99363265e+00, -4.16589997e+00, -1.04230798e+01,
#         1.21852931e+01, -7.27726942e-01, -4.58625626e+00, -2.49477160e+01,
#        -7.68917011e+00,  4.49292029e+00, -3.16119422e+00, -9.43138319e+00,
#         9.12979395e+00,  9.12760268e-01, -2.20606655e+00, -5.73123172e+00,
#         2.27421263e+00,  1.44665812e+00,  8.69875424e+00,  4.89480132e+00,
#        -3.48543451e+00,  1.36065027e+01, -1.01076611e+01, -2.31125082e+01,
#         5.66336425e-01,  3.57197909e+00, -9.23451428e-01,  8.72504175e+00,
#        -1.49525813e+01, -6.46633657e+00, -1.43340012e+01,  5.14327325e-01,
#         5.47557123e+00,  5.13724608e+00, -4.50433117e+00, -1.01335354e+01,
#         2.92213021e+00,  6.97911135e+00, -1.00048630e+01, -1.18645217e+01,
#        -6.77533952e+00,  3.53001372e+00,  4.41347708e+00,  2.53128630e+01,
#         1.50474083e-01, -7.45885556e+00, -1.22334728e+01,  3.35000030e+00,
#        -3.72811885e+00, -2.35576460e+00,  3.93110655e-01, -6.39566327e+00,
#         9.27268571e+00,  1.73124341e+00,  4.23143504e-01,  3.70674425e+00,
#         5.98768311e+00, -7.02889945e-01, -8.09625053e+00,  2.32113288e+00,
#         1.22665606e+01, -8.80622322e+00, -2.56138455e+01,  4.51654322e-01,
#        -1.56902269e+01,  3.46597052e+00,  1.29547438e+00,  1.22824885e+01,
#        -5.74563363e+00,  6.39914650e+00,  7.10918660e+00, -1.97139206e+01,
#        -8.55330592e+00,  1.74147354e+01,  4.00461789e-02, -6.90707180e+00,
#        -5.29377361e+00,  1.44790755e+01,  5.41466917e+00, -3.32237052e+00,
#         1.29681312e+00,  5.76609088e+00,  4.42826892e+00,  3.65408082e+00,
#         1.95181908e+00,  3.78335820e+00,  7.29379157e+00,  6.23748856e+00,
#         1.92918854e+01,  8.90514369e+00, -7.19531697e-01, -9.82665440e-01,
#        -5.69883973e-01, -3.38158887e+00, -1.36706547e+00, -7.59951423e+00,
#         1.60401203e+01, -8.64523972e+00, -3.42520313e+00, -1.31408302e+00,
#         5.36896452e+00,  5.06811490e+00, -1.00938118e+01,  1.80918567e+00,
#        -1.48844240e+01,  1.25420807e+01, -1.91041262e+01,  1.19803009e+01,
#         7.61588042e+00,  1.27434572e+01,  1.86553041e+00, -4.54870934e+00,
#        -5.30295337e+00, -1.48589854e+01,  4.65194927e+00, -1.08791598e+01,
#        -1.75455883e+01, -5.66579921e+00,  7.39732361e+00,  3.90468843e-01,
#         5.99451500e+00, -1.18664037e+00, -1.30528561e+01,  5.21287194e+00,
#         2.26182813e+00,  9.51991807e+00, -1.09944120e+01, -7.19419403e+00,
#        -6.86855309e+00, -9.54779261e+00, -1.01493913e+01,  7.98822757e+00,
#        -2.99255827e+00,  5.61536665e+00,  2.19026404e+00,  2.07233910e+00,
#        -2.14391291e+00, -1.52037677e+01, -1.44794275e+00,  3.13529136e+00,
#        -1.89744312e+01,  2.45778859e+01,  8.41243516e+00, -5.68830450e+00,
#        -2.20816979e+00,  2.02201715e+00, -1.38347381e+01,  5.85891522e+00,
#        -2.37295772e+00, -1.56067618e+01,  1.82723466e+00, -1.10497217e+01,
#        -9.72359859e+00,  2.04386809e+00, -1.29645981e+01,  3.47300657e+00,
#         7.48437548e-02, -4.68783741e+00, -7.20440117e+00,  1.43094359e+01,
#        -6.28013106e+00,  5.30538334e+00,  7.59166947e+00,  1.41509857e+01,
#        -1.50189221e+00, -7.72670628e+00, -9.78305360e+00,  1.18567633e+01,
#        -1.45811628e+01, -1.37339233e+01, -2.11182074e+01, -9.77400703e+00,
#         1.35756505e+01, -1.14027521e+01, -1.37442309e+01, -4.25628435e+00,
#        -1.33404681e+01, -1.21084926e+01,  9.77194030e+00, -1.36280532e+01,
#        -5.82864443e+00,  2.96654402e+01, -2.50474446e+01, -2.43772796e+01,
#        -6.60263281e-01, -8.84378093e+00,  3.31936519e+00,  9.37654238e+00,
#         3.35893985e+00,  5.36375057e+00, -4.29344260e+00,  1.05170720e+01,
#         4.93495169e+00,  2.07372290e+01, -2.46118341e+00,  4.68878178e-01,
#         3.67988053e+00, -2.40015284e+00, -1.58242937e+01,  2.35707697e+01,
#         3.64283976e+00, -4.45114215e+00,  4.15531625e+00,  4.97569880e+00,
#        -2.48149157e+01,  1.25900346e+00,  4.96605750e+00, -8.56504080e+00,
#        -2.06522655e+00, -5.73651521e+00, -4.81971717e+00, -6.12473552e+00,
#         2.06391037e+01, -2.09681037e+01, -2.39897789e+00, -1.88587819e+00,
#        -5.52951113e+00, -2.76083506e+00, -3.51854938e+00, -1.46607983e+00,
#         1.52493923e+01,  1.25133423e+01,  5.81325067e+00, -1.56732739e+01,
#         1.04795266e+01, -1.72513351e+00,  7.62866600e+00, -1.58762707e+01,
#        -1.27337110e+01,  1.85762656e+01, -4.29240486e+00, -4.58013907e+00,
#        -1.63062235e+01, -2.67536894e+00, -1.31100854e+01, -7.69495147e+00,
#        -3.46589285e+00, -7.46904970e-01, -1.11959580e+01, -7.51052089e+00,
#        -3.19309365e+00,  1.10340360e+01,  1.62097499e+01,  3.21577776e+00,
#        -6.09616261e+00, -9.34296529e-01, -4.78720380e+00, -6.72615455e+00,
#        -4.22939360e+00,  1.43604291e+01,  8.45486383e+00,  8.71299800e+00,
#         1.56708020e+01,  5.77499061e+00,  1.01442253e+01, -9.15759575e+00,
#        -7.57808342e+00,  1.07834336e+01,  5.54824068e+00, -2.43384760e+00,
#         1.61756790e+01,  7.36078649e+00,  5.26869748e+00, -1.48711972e+01,
#         9.82111724e+00,  9.54737216e+00, -2.38216409e+00, -1.13267575e+01,
#         2.41368324e+00, -4.91400523e+00, -1.28839033e+01, -4.14408137e+00,
#        -2.33460778e+00,  1.45948711e+01, -2.65416113e+01,  6.39216470e+00,
#         9.38630186e+00,  7.64554201e+00, -5.86793300e+00, -5.09005121e+00,
#         8.43596280e+00, -1.30022999e+01,  1.45403741e+01, -5.22234225e+00,
#        -2.53061867e+00, -1.89681872e+00, -1.59399151e+01,  6.57516744e+00,
#        -1.69918477e+00,  6.76443799e+00,  2.11005889e+00, -2.95268445e+00,
#        -3.78989060e+00, -1.74341942e+01,  2.59802412e+00, -3.44167200e+00,
#        -9.83228071e+00,  6.15188196e+00, -1.95925741e+00, -4.74318136e+00,
#        -2.36757615e-01,  2.80426419e+01, -7.62680559e+00,  3.39293952e+00,
#         2.72111514e+00, -3.59984782e+00,  1.20694176e+01, -1.09230648e+01,
#        -2.68850073e+01,  2.76567175e-01, -4.49896604e-01,  8.49315352e+00,
#         1.81382494e+00, -3.79467502e+00,  1.01989241e+01,  2.86317246e+00])

# %% [markdown]
# <a href="https://github.com/browntruck246/Data-Science/blob/main/Data-Science-Foundations-Python/context.md">Context</a>
